# %% [markdown]
# <a href="https://colab.research.google.com/github/rijojz/Introduction-to-Tensor-Flow/blob/master/Week1_housing_prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
model = tf.keras.Sequential([keras.layers.Dense(units = 1, input_shape = [1])])
model.compile(optimizer = 'sgd' , loss = 'mean_squared_error')
xs = np.array([1,2,3,4,5,8], dtype = float)
ys = np.array([1,1.5, 2, 2.5, 3, 5], dtype = float)
model.fit(xs, ys, epochs = 700)
model.predict([7.0])
# Out:
# Epoch 1/700
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3632
# Epoch 2/700
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8506
# Epoch 3/700
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3267
# Epoch 4/700
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1452
# Epoch 5/700
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0821
# Epoch 6/700
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0600
# Epoch 7/700
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0521
# Epoch 8/700
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0492
# Epoch 9/700
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0479
# Epoch 10/700
# 1/1 [==============================] - 0s 940us/step - loss: 0.0472
# Epoch 11/700
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0468
# Epoch 12/700
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0464
# ...

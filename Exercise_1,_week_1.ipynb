# %% [markdown]
# <a href="https://colab.research.google.com/github/rijojz/Introduction-to-Tensor-Flow/blob/master/Exercise_1%2C_week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([0.0, 1.0, 2.0, 3.0, 4.0, 10], dtype=float)
ys = np.array([0.5, 1.0, 1.5, 2.0, 2.5, 5.5], dtype=float)

# %%
model.fit(xs, ys, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 19.6916
# Epoch 2/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 6.2278
# Epoch 3/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0604
# Epoch 4/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7687
# Epoch 5/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3667
# Epoch 6/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2399
# Epoch 7/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1982
# Epoch 8/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1830
# Epoch 9/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1760
# Epoch 10/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1716
# Epoch 11/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1680
# Epoch 12/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1647
# ...

# %%
print(model.predict([7.0]))
# Out:
# [[4.000005]]
